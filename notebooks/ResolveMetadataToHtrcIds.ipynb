# %% [markdown]
# # Resolve Metadata to HTRC IDs

# %% [markdown]
# This notebook is a part of work being done for [The Trace of Theory project](https://www.hathitrust.org/htrc_acs_awards_spring2015), a collaboration between researchers of [NovelTM](http://novel-tm.ca/) and the HathiTrust Research Center ([HTRC](https://www.hathitrust.org/)).
#
# In particular, we are wanting to use both [supervised](https://en.wikipedia.org/wiki/Supervised_learning) and [unsupervised](https://en.wikipedia.org/wiki/Unsupervised_learning) machine learning techniques on HTRC texts to gain a better understanding of the extent and nature of theory in various genres.
#
# A step along the way has been to develop a list of theoretical texts in both philosophical and literary genres (about 100 texts in each list). We've created lists of authors and titles, but we now need a way to reference this against specific items in the HTRC corpus. To accomplish this, we'll create a very simple mechanism that produces a query from the author and title fields that can be used with HTRC API (see [HTRC Technical Documents]( https://wiki.htrc.illinois.edu/display/COM/HTRC+Technical+Documents) for more info).
#
# This is a summary of what we'll do:
#
# * define a function to produce a Solr query from metadata
# * define a function to retrieve candidate IDs from the HTRC API using our query
# * define a function to add a column to a table that already defines author and title values
# * use these functions to resolve HTRC IDs in our list of philosophical and literary texts

# %% [markdown]
# ## Produce Solr-compatible Query from Metadata

# %% [markdown]
# In order to prepare a query for the HTRC API we need to look at the existing metadata and treat different fields differently. For instance, authors can come in various forms (such as "Atwood, Margeret", "Margeret Atwood", "M. Atwood"), so we'll create query component that uses the full names (not abbreviations) that are present, in any order. Word order does matter for titles, so we'll try to make a phrase from the existing title string (we'll strip out non-alphanumeric and additional whitespace characters since the HTRC query engine will likely do that anyway).

# %%
import re

# This takes metadata passed as arguments and produces a Solr-compatible query parameter.
# Though we're only using author and title at the moment, we're defining this flexibly to
# allow for further functionality.
def get_solr_query(**kwargs):
    
    atoms = [] # keep track of the parts of our query
    
    if 'author' in kwargs: # look for author metadata
        atoms += ["author:"+word for word in re.split('\W+', kwargs['author']) if len(word) > 1]
    
    if 'title' in kwargs: # look for title metadata
        atoms.append('title:"'+re.sub('\W+', ' ', kwargs['title'])+'"')

    return ' AND '.join(atoms)

# %% [markdown]
# ## Fetch HTRC IDs from a Query

# %% [markdown]
# Now that we can produce a Solr-compatble query, let's define a function that calls the HTRC API with the query and extracts from the response the desired IDs. It's worth noting that a query might result in zero, one or many results (up to 10 based on the default limit).

# %%
base_url = 'http://chinkapin.pti.indiana.edu:9994/solr/meta/select/?' # sandbox URL

import urllib.request
import xml.etree.ElementTree as ET

# This takes metadata passed as arguments and tries to resolve it to a list of IDs.
def get_ids(**kwargs):
    
    # fetch contents (no real error checking at the moment)
    url = base_url + urllib.parse.urlencode({'q': get_solr_query(**kwargs)})
    response = urllib.request.urlopen(url)
    xml = response.read()
    
    # parse XML contents
    root = ET.fromstring(xml)
    return [element.text for element in root.findall(".//str[@name='id']")]

# %% [markdown]
# ## Append ID Column to a Metadata Table

# %% [markdown]
# Now that we have function to retrieve HTRC IDs from metadata all that's left to do is to create a function that enhances an existing metadata table by adding a column for the IDs. For the sake of convenience we'll rely on [Pandas](http://pandas.pydata.org/) to manage our data tables.

# %%
import pandas as pd

# Take an existing Pandas DataFrame with metadata and add a column with IDs
def append_ids(dataFrame):
    dataFrame['ids'] = pd.Series(dataFrame.count(), index=dataFrame.index)
    for index, row in dataFrame.iterrows():
        ids = get_ids(**row.to_dict())
        dataFrame.ix[index,'ids']=';'.join(ids)

# %% [markdown]
# ## Enhance Lists of Philosophy and Literary Texts

# %% [markdown]
# Everything is ready for us to use, we'll read in each of the existing metadata files and produce output with the ids. The source datafiles were exported as comma-separated values from Excel (files provided by Geoffrey and Laura with slight edits to the header row).

# %%
import pandas as pd
from IPython.core.display import HTML, display

# read in source metadata file and output enhanced metadata file
def enhance_list(file_base, extension="tsv"):
    dataFrame = pd.read_table(file_base+"."+extension)
    append_ids(dataFrame)
    dataFrame.to_csv(file_base+"-with-ids."+extension, index=False, sep="\t")
    display(HTML(dataFrame.to_html()))

# %% [markdown]
# ### Philosophy List

# %%
enhance_list("philosophy-list")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>author</th>
#       <th>title</th>
#       <th>ids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Plato</td>
#       <td>The Republic</td>
#       <td>hvd.32044077696110;nyp.33433081632998;mdp.3901...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Plato</td>
#       <td>Theaetetus</td>
#       <td>hvd.hn3kts;hvd.32044010441350;uc2.ark:/13960/t...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Plato</td>
#       <td>Apology</td>
#       <td>uc1.31822009493982;mdp.39015001808750;loc.ark:...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Plato</td>
#       <td>Phaedrus</td>
#       <td>hvd.hxjfcr;mdp.39015004072206;uc1.c072610589;m...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Plato</td>
#       <td>Euthyphro</td>
#       <td>uc1.b3922458;uc2.ark:/13960/t1sf2x49r;uc1.$b68...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Aristotle</td>
#       <td>Politics</td>
#       <td>uiug.30112055523101;mdp.39015066423750;mdp.390...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Aristotle</td>
#       <td>The Categories</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Aristotle</td>
#       <td>Poetics</td>
#       <td>hvd.32044010427722;hvd.32044012915443;uc2.ark:...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Aristotle</td>
#       <td>Ethics</td>
#       <td>uc2.ark:/13960/t9q23t861;mdp.39015065617824;md...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Aristotle</td>
#       <td>The Nicomachean Ethics</td>
#       <td>uc1.32106000024569;nnc1.50207993;uc1.a00036588...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>George John Romanes</td>
#       <td>Mind and Motion and Monism</td>
#       <td>mdp.39015001982290;wu.89094555117;uc1.$b191943...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Marcus Aurelius</td>
#       <td>Meditations</td>
#       <td>mdp.39015027923807;uva.x030802906;njp.32101020...</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Lucretius</td>
#       <td>On the Nature of Things</td>
#       <td>hvd.32044005055405;uc1.32106001545372;uc1.3210...</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Alexander Philip</td>
#       <td>Essays Towards a Theory of Knowledge</td>
#       <td>uc1.$b279047;uc2.ark:/13960/t4qj7982v</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Immanuel Kant</td>
#       <td>The Critique of Pure Reason</td>
#       <td>uc2.ark:/13960/t45q5691k</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Immanuel Kant</td>
#       <td>Critique of Practical Reason</td>
#       <td>uva.x002166055;mdp.39015004129899;nc01.ark:/13...</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Ludwig Wittgenstein</td>
#       <td>Tractatus Logico-Philosophicus</td>
#       <td>mdp.39015001539116;uc1.31175026845241</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Bertrand Russell</td>
#       <td>The Problems of Philosophy</td>
#       <td>mdp.39015048991148;ucw.ark:/13960/t6834gk78;md...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Bertrand Russell</td>
#       <td>Mysticism and Logic and Other Essays</td>
#       <td>uc2.ark:/13960/t2h70b65n;inu.30000043372204;md...</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Bertrand Russell</td>
#       <td>The Analysis of Mind</td>
#       <td>uva.x000092282;mdp.39015002885542;ucw.ark:/139...</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Bertrand Russell</td>
#       <td>Proposed Roads to Freedom</td>
#       <td>mdp.39015028389438;uva.x000199762;hvd.32044032...</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Bertrand Russell</td>
#       <td>Political Ideals</td>
#       <td>mdp.39015008630637;uc2.ark:/13960/t7tm74w9p</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Peter Coffey</td>
#       <td>Ontology or the Theory of Being</td>
#       <td>mdp.39015026428428;wu.89094578374</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>René Descartes</td>
#       <td>Discourse on Method</td>
#       <td>mdp.39015001149858</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>René Descartes</td>
#       <td>Rules for the Direction of the Mind</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Blaise Pascal</td>
#       <td>Pensées</td>
#       <td>uc1.$b498546;uc1.b000758318;uc1.b000758319;ucm...</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>George Berkeley</td>
#       <td>A Treatise Concerning the Principles of Human...</td>
#       <td>uc1.$b54740;uc2.ark:/13960/t74t6tc5s;hvd.32044...</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>George Berkeley</td>
#       <td>Three Dialogues Between Hylas and Philonous</td>
#       <td>uc2.ark:/13960/t6b27rv7k;mdp.39015002843004;ui...</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Thomas Hobbes</td>
#       <td>Leviathan</td>
#       <td>mdp.39015005032472;mdp.39015005510410;mdp.3901...</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Georg Wilhelm Friedrich Hegel</td>
#       <td>Phenomenology of Spirit</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Georg Wilhelm Friedrich Hegel</td>
#       <td>The Philosophy of Right</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Georg Wilhelm Friedrich Hegel</td>
#       <td>The Philosophy of History</td>
#       <td>loc.ark:/13960/t24b3wk11;uc2.ark:/13960/t3028s...</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Arthur Schopenhauer</td>
#       <td>The World as Will and Representation</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Søren Kierkegaard</td>
#       <td>Either/Or</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Søren Kierkegaard</td>
#       <td>Fear and Trembling</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Mary Wollstonecraft</td>
#       <td>A Vindication of the Rights of Women</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Karl Marx</td>
#       <td>Das Kapital</td>
#       <td>mdp.39015011382820;nnc1.cu09896988;nnc1.cu5655...</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Friedrich Nietzsche</td>
#       <td>Thus Spoke Zarathustra</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Friedrich Nietzsche</td>
#       <td>On the Genealogy of Morals</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>David Hume</td>
#       <td>An Enquiry Concerning Human Understanding</td>
#       <td>mdp.39015005481109;loc.ark:/13960/t56d6pj1c;ny...</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>David Hume</td>
#       <td>A Treatise of Human Nature</td>
#       <td>uc1.b4251391;uc1.b4251934;uva.x000093815;uc1.3...</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Benedictus de Spinoza</td>
#       <td>Improvement of the Understanding</td>
#       <td>mdp.39015004981091;uc1.b4251452;mdp.3901504922...</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Benedictus de Spinoza</td>
#       <td>Ethics</td>
#       <td>mdp.39015049220422;hvd.32044009503269;uc1.b392...</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>John Locke</td>
#       <td>An Essay Concerning Human Understanding</td>
#       <td>mdp.39015030048469;mdp.39015030048451;uva.x000...</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>John Locke</td>
#       <td>Two Treatises of Government</td>
#       <td>hvd.32044009555855;uiug.30112039642811;njp.321...</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>John Abercrombie</td>
#       <td>The Philosophy of the Moral Feeling</td>
#       <td>loc.ark:/13960/t9960r10p;loc.ark:/13960/t0tq73...</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Adam Smith</td>
#       <td>The Wealth of Nations</td>
#       <td>njp.32101075729655;njp.32101075729663;njp.3210...</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Jean-Jacques Rousseau</td>
#       <td>The Social Contract</td>
#       <td>mdp.39015005762060;wu.89002175727;mdp.39015054...</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Jean-Jacques Rousseau</td>
#       <td>Emile</td>
#       <td>wu.89101288959;wu.89101288934;wu.89101288942;m...</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>John Stuart Mill</td>

# %%
## Literary List

# %%
enhance_list("literary-list")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>author</th>
#       <th>title</th>
#       <th>ids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Aristotle</td>
#       <td>Poetics</td>
#       <td>hvd.32044010427722;hvd.32044012915443;uc2.ark:...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Aristotle</td>
#       <td>Rhetoric</td>
#       <td>mdp.39015005479871;mdp.39015051095548;njp.3210...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Horace</td>
#       <td>Ars Poetica / Art of Poetry</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Longinus</td>
#       <td>On the Sublime</td>
#       <td>umn.31951001668292k;mdp.39015004928894;hvd.320...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Philip Sidney</td>
#       <td>An Apology for Poetry</td>
#       <td>mdp.39015011889204;gri.ark:/13960/t87h3t70j;hv...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Pierre Corneille</td>
#       <td>Of the Three Unities</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>John Dryden</td>
#       <td>An Essay of Dramatic Poesy</td>
#       <td>uc1.$b272452;mdp.39015030940434;mdp.3901503123...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Nicolas Boileau-Despreaux</td>
#       <td>The Art of Poetry</td>
#       <td>mdp.39015059894330;mdp.39015008498340;njp.3210...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>John Dennis</td>
#       <td>The Advancement and Reformation of Modern Poetry</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Alexander Pope</td>
#       <td>An Essay on Criticism</td>
#       <td>pst.000005296095;mdp.39015000549983;nyp.334330...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Joseph Warton</td>
#       <td>An Essay on the Genius and Writings of Pope</td>
#       <td>nyp.33433074793658;nyp.33433074793633;nyp.3343...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Joseph Addison</td>
#       <td>The Spectator (1712 volume; numbers 411, 416, ...</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Giambattista Vico</td>
#       <td>The New Science</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Thomas Warton</td>
#       <td>The History of English Poetry</td>
#       <td>hvd.hn1cxp;hvd.32044004355939;uc2.ark:/13960/t...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Edmund Burke</td>
#       <td>A Philosophical Enquiry into the Origin of our...</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>David Hume</td>
#       <td>Of the Standard of Taste in Four Dissertations</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Samuel Johnson</td>
#       <td>Preface to Shakespeare</td>
#       <td>inu.30000005470244;njp.32101068599818;uc1.b534...</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Samuel Johnson</td>
#       <td>Lives of the Poets</td>
#       <td>umn.31951002044523l;umn.31951002044524j;umn.31...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Samuel Johnson</td>
#       <td>Rambler (1750 volume, number 4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Edward Young</td>
#       <td>Conjectures on Original Composition</td>
#       <td>njp.32101004972418;mdp.39015019990194;loc.ark:...</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Joshua Reynolds</td>
#       <td>Discourses on Art</td>
#       <td>mdp.39015031965372</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Immanuel Kant</td>
#       <td>Critique of Judgment</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Friedrich von Schiller</td>
#       <td>Letters on the Aesthetic Education of Man</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Denis Diderot</td>
#       <td>Rameau's Nephew</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Denis Diderot</td>
#       <td>Salons</td>
#       <td>hvd.32044108418336;hvd.32044108418344;hvd.3204...</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>William Wordsworth</td>
#       <td>Preface, Lyrical Ballads -- 1800 edition</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Samuel Taylor Coleridge</td>
#       <td>Biographia Literaria</td>
#       <td>wu.89001272749;mdp.39015004729847;nyp.33433082...</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Samuel Taylor Coleridge</td>
#       <td>On the Principles of Genial Criticism</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Friedrich Wilhelm von Schelling</td>
#       <td>On the Relation of the Plastic Arts to Nature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>John Keats</td>
#       <td>Letters</td>
#       <td>hvd.32044019172667;mdp.39015011528232;hvd.3204...</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Jean-Jacques Rousseau</td>
#       <td>Letter to M. D'Alembert on Spectacles</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Thomas Love Peacock</td>
#       <td>The Four Ages of Poetry</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Percy Bysshe Shelley</td>
#       <td>A Defense of Poetry</td>
#       <td>mdp.39015065528443;hvd.32044021220181;mdp.3901...</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Johann Wolfgang von Goethe</td>
#       <td>Conversations with Eckermann</td>
#       <td>nyp.33433082516414;nyp.33433082516422;nyp.3343...</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Georg Wilhelm Friedrich Hegel</td>
#       <td>The Philosoophy of Fine Art</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Thomas Carlyle</td>
#       <td>Sartor Resartus</td>
#       <td>mdp.39015011431783;loc.ark:/13960/t2w38dz8v;uc...</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>John Stuart Mill</td>
#       <td>What is Poetry? Monthly Repository -- 1833</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>John Stuart Mill</td>
#       <td>Thoughts on Poetry and Its Varieties</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Charles-Augustin Sainte-Beuve</td>
#       <td>What is a Classic? in Select Essays</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Matthew Arnold</td>
#       <td>The Function of Criticism at the Present Time</td>
#       <td>loc.ark:/13960/t0ms47t1z;hvd.32044097036271</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Matthew Arnold</td>
#       <td>The Study of Poetry</td>
#       <td>uva.x001190929;uiug.30112039689739</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Hippolyte Taine</td>
#       <td>The History of English Literature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>John Ruskin</td>
#       <td>Modern Painters</td>
#       <td>mdp.39015039478600;mdp.39015039478592;mdp.3901...</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Charles Baudelaire</td>
#       <td>The Salon of 1859</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Friedrich Nietzsche</td>
#       <td>The Birth of Tragedy from the Spirit of Music</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Walter Pater</td>
#       <td>Studies in the History of the Renaissance</td>
#       <td>nyp.33433082475124</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Emile Zola</td>
#       <td>The Experimental Novel</td>
#       <td>mdp.39015008653944;uc2.ark:/13960/t0vq2v80g;md...</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Henry James</td>
#       <td>The Art of the Novel</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Henry James</td>
#       <td>French Poets and Novelists</td>
#       <td>uc1.32106001715694;njp.32101072917055;hvd.3204...</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Henry James</td>
#       <td>Hawthorne</td>
#       <td>uc1.32106002070602;hvd.32044011362068;uc1.3210...</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Henry James</td>
#       <td>Parial Portraits</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>Henry James</td>
#       <td>View and Reviews</td>
#       <td>mdp.39015066051551;loc.ark:/13960/t62524q70</td>

# %% [markdown]
# --_
# Stéfan Sinclair, Creative Commons (CC-BY)
